# %%
from datetime import datetime
import pytz

senha_padrao = "1234"
saldo = 0.0
extrato = []

def data_hora():
    """ Retorna a data e hora atual no fuso horário de Brasília. """
    fuso_brasilia = pytz.timezone("America/Sao_Paulo")
    data_hora_brasil = datetime.now(fuso_brasilia)
    return data_hora_brasil.strftime("%d/%m/%Y %H:%M:%S")

def ver_saldo():
    """ Retorna o saldo formatado. """
    return f"Seu saldo: R$ {saldo:.2f} - {data_hora()}"

def deposito():
    """ Realiza um depósito na conta. """
    global saldo
    valor_deposito = float(input("Informe o valor do deposito : "))
    if valor_deposito > 0:
        saldo += valor_deposito
        extrato.append(f"Depósito de R$ {valor_deposito:.2f} em {data_hora()}")
        print(f"Depósito realizado com sucesso. Seu saldo atual é R$ {saldo:.2f}.")
    else:
        print("Erro: O valor é insuficiente.")


def saque():
    """ Realiza um saque, se o saldo for suficiente. """
    global saldo
    valor_saque = float(input("Informe o valor do saque: "))
    if valor_saque > 0 and valor_saque <= saldo:
        saldo -= valor_saque
        extrato.append(f"Saque de R$ {valor_saque:.2f} em {data_hora()}")
        print(f"Saque realizado com sucesso. Seu saldo atual é R$ {saldo:.2f}.")
    else:
        print("Erro: Saldo insuficiente ou valor inválido.")

def exibir_extrato():
    """ Exibe todas as movimentações da conta. """
    if not extrato:
        print("Nenhuma movimentação realizada.")
    else:
        for tipo in extrato:

          print(f"Extrato das movimentações: R${tipo}")




# Menu interativo
while True:
    print("\n=== Caixa Eletrônico ===")
    print("\n1. Depositar\n2. Sacar\n3. Ver Saldo\n4. Extrato\n5. Sair")
    opcao = input("Escolha uma opção: ")
    tentativas=3
    while tentativas>0:
      if input("Digite sua senha: ") == senha_padrao:
          print("Senha correta. Acesso permitido.")
          break


      tentativas-=1
      print(f"Senha incorreta! Tentativas Restantes: {tentativas}")

    if tentativas ==0:

      print("Conta Bloqueada")
      break

    if opcao == "1":
        deposito()
    elif opcao == "2":
        saque()
    elif opcao == "3":
        print(ver_saldo())
    elif opcao == "4":
        exibir_extrato()
    elif opcao == "5":
        print(f"Operações finalizadas. Seu saldo final é R$ {saldo:.2f}.")
        break
    else:
        print("Opção inválida. Escolha novamente.")
# Out:
# === Caixa Eletrônico ===
#
# 1. Depositar
# 2. Sacar
# 3. Ver Saldo
# 4. Extrato
# 5. Sair
# Escolha uma opção: 1
# Digite sua senha: 1234
# Senha correta. Acesso permitido.
# Informe o valor do deposito : 100
# Depósito realizado com sucesso. Seu saldo atual é R$ 100.00.
#
# === Caixa Eletrônico ===
#
# 1. Depositar
# 2. Sacar
# 3. Ver Saldo
# 4. Extrato
# 5. Sair
# Escolha uma opção: 2
# Digite sua senha: 1234
# Senha correta. Acesso permitido.
# Informe o valor do saque: 40
# Saque realizado com sucesso. Seu saldo atual é R$ 60.00.
#
# === Caixa Eletrônico ===
#
# 1. Depositar
# 2. Sacar
# 3. Ver Saldo
# 4. Extrato
# 5. Sair
# Escolha uma opção: 3
# Digite sua senha: 1234
# Senha correta. Acesso permitido.
# Seu saldo: R$ 60.00 - 21/02/2025 18:11:11
#
# === Caixa Eletrônico ===
#
# 1. Depositar
# 2. Sacar
# 3. Ver Saldo
# 4. Extrato
# 5. Sair
# Escolha uma opção: 4
# Digite sua senha: 1234
# Senha correta. Acesso permitido.
# Extrato das movimentações: R$Depósito de R$ 100.00 em 21/02/2025 18:09:58
# Extrato das movimentações: R$Saque de R$ 40.00 em 21/02/2025 18:10:58
#
# === Caixa Eletrônico ===
#
# 1. Depositar
# 2. Sacar
# 3. Ver Saldo
# 4. Extrato
# 5. Sair
# Escolha uma opção: 1
# Digite sua senha: 1346
# Senha incorreta! Tentativas Restantes: 2
# Digite sua senha: 2346
# Senha incorreta! Tentativas Restantes: 1
# Digite sua senha: 1256
# Senha incorreta! Tentativas Restantes: 0
# Conta Bloqueada
